# %%
pip install pywhatkit
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.2 kB 1.4 MB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.2 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 408.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
import pywhatkit

# pywhatkit.sendwhatmsg("+919925272499", "Hello CHATGPT testcase1", 15, 1)
# pywhatkit.sendwhatmsg("+919925272499", "Hello CHATGPT testcase1", 14, 57)
# pywhatkit.sendwhatmsg("+919925272499", "Hello CHATGPT testcase1", 14, 57)
# pywhatkit.sendwhatmsg("+919925272499", "Hello CHATGPT testcase1", 14, 57)
pywhatkit.sendwhatmsg("+917043363037", "Hello CHATGPT testcase1.3", 15, 14, 5)
pywhatkit.sendwhatmsg("+919714538950", "Hello CHATGPT testcase1.3", 15, 14, 5)
pywhatkit.sendwhatmsg("+919537939637", "Hello CHATGPT testcase1.3", 15, 14, 5)
pywhatkit.sendwhatmsg("+919825184236", "Hello CHATGPT testcase1.3", 15, 14, 5)
